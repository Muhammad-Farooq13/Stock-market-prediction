# %% [markdown]
# # Stock Market Data Exploration and Analysis
#
# This notebook provides a comprehensive exploration of the stock market dataset, including:
# - Data loading and inspection
# - Exploratory Data Analysis (EDA)
# - Feature engineering
# - Model training and evaluation
# - Visualization of results

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("Libraries imported successfully!")

# %%
# Import custom modules
import sys
sys.path.append('..')

from src.data.load_data import DataLoader
from src.data.preprocessing import DataPreprocessor
from src.features.feature_engineering import FeatureEngineer
from src.models.train_model import ModelTrainer
from src.models.evaluate_model import ModelEvaluator
from src.visualization.visualize import Visualizer

print("Custom modules imported successfully!")

# %% [markdown]
# ## 1. Data Loading

# %%
# Initialize data loader
loader = DataLoader()

# Load the stock market data
df = loader.load_stock_data()

print(f"Dataset shape: {df.shape}")
print(f"\nFirst few rows:")
df.head()

# %% [markdown]
# ## 2. Data Overview

# %%
# Get data information
info = loader.get_data_info(df)

print("=== Dataset Information ===")
print(f"Shape: {info['shape']}")
print(f"\nColumns: {info['columns']}")
print(f"\nMemory Usage: {info['memory_usage']:.2f} MB")
print(f"Duplicate Rows: {info['duplicate_rows']}")

# Display data types
print("\n=== Data Types ===")
df.dtypes

# %%
# Display basic statistics
print("=== Basic Statistics ===")
df.describe()

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': missing_values.index,
    'Missing Count': missing_values.values,
    'Percentage': missing_percent.values
})

missing_df = missing_df[missing_df['Missing Count'] > 0].sort_values('Missing Count', ascending=False)

if len(missing_df) > 0:
    print("=== Missing Values ===")
    display(missing_df)
else:
    print("No missing values found!")

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
# Initialize visualizer
visualizer = Visualizer()

# Note: Adjust column names based on your actual dataset
# Example: If you have 'Close', 'Date' columns
# numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()
# if len(numeric_columns) > 0:
#     visualizer.plot_distribution(df, numeric_columns[:6], "Feature Distributions")

# %%
# Correlation matrix
numeric_df = df.select_dtypes(include=[np.number])
if numeric_df.shape[1] > 1:
    visualizer.plot_correlation_matrix(numeric_df, "Correlation Matrix")

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Initialize feature engineer
engineer = FeatureEngineer()

# Create features
# Note: Adjust column names based on your dataset
# Example:
# df_features = engineer.create_all_features(df, price_column='Close', date_column='Date')
# print(f"\nOriginal features: {df.shape[1]}")
# print(f"Total features after engineering: {df_features.shape[1]}")
# print(f"New features created: {len(engineer.created_features)}")

# %% [markdown]
# ## 5. Data Preprocessing

# %%
# Initialize preprocessor
preprocessor = DataPreprocessor()

# Run preprocessing pipeline
# Note: Adjust column names based on your dataset
# data = preprocessor.preprocess_pipeline(df_features, target_column='Close', date_column='Date')

# print("\n=== Preprocessed Data Shapes ===")
# print(f"X_train: {data['X_train'].shape}")
# print(f"X_val: {data['X_val'].shape}")
# print(f"X_test: {data['X_test'].shape}")

# %% [markdown]
# ## 6. Model Training

# %%
# Initialize model trainer
trainer = ModelTrainer()

# Train multiple models
# results = trainer.train_multiple_models(
#     data['X_train'], data['y_train'],
#     data['X_val'], data['y_val'],
#     model_names=['linear_regression', 'random_forest', 'xgboost']
# )

# %% [markdown]
# ## 7. Model Evaluation

# %%
# Initialize evaluator
evaluator = ModelEvaluator()

# Evaluate models
# model_dict = {name: result[0] for name, result in results.items()}
# comparison = evaluator.evaluate_multiple_models(model_dict, data['X_test'], data['y_test'])

# print("\n=== Model Comparison ===")
# display(comparison)

# %% [markdown]
# ## 8. Visualization of Results

# %%
# Plot predictions vs actual
# best_model_name = comparison.iloc[0]['model']
# best_model = model_dict[best_model_name]

# y_pred = best_model.predict(data['X_test'])
# visualizer.plot_predictions_vs_actual(
#     data['y_test'].values,
#     y_pred,
#     title=f"{best_model_name} - Predictions vs Actual"
# )

# %%
# Plot residuals
# visualizer.plot_residuals(
#     data['y_test'].values,
#     y_pred,
#     title=f"{best_model_name} - Residual Analysis"
# )

# %%
# Feature importance
# importance = trainer.get_feature_importance(best_model, data['feature_names'], top_n=20)
# if importance is not None:
#     visualizer.plot_feature_importance(importance, title=f"{best_model_name} - Feature Importance")

# %% [markdown]
# ## 9. Save Best Model

# %%
# Save the best model
# best_metrics = results[best_model_name][1]
# trainer.save_model(best_model, best_model_name, metadata=best_metrics)

# print(f"\nBest model '{best_model_name}' saved successfully!")

# %% [markdown]
# ## 10. Conclusions
#
# ### Key Findings:
# 1. [Add your findings here]
# 2. [Model performance summary]
# 3. [Feature importance insights]
#
# ### Next Steps:
# 1. Deploy the best model using Flask API
# 2. Set up MLOps pipeline for continuous monitoring
# 3. Implement real-time prediction capabilities
